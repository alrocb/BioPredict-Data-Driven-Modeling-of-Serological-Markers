# %%
from pycaret.datasets import get_data
diabetes = get_data('diabetes')

# init setup
from pycaret.classification import *
clf1 = setup(data = diabetes, target = 'Class variable')

# create a model
dt = create_model('dt')

# save pipeline
save_model(dt, 'dt_pipeline')

# load pipeline
load_model('dt_pipeline')

# %%
from pycaret.classification import *
model= load_model('best_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
convert_model(model, 'java')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 convert_model(model, 'java')
#
# File c:\Users\bntmm\.conda\envs\biopredenv\lib\site-packages\pycaret\utils\generic.py:963, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     961 for name, message in global_names.items():
#     962     if globals_d[name] is None:
# --> 963         raise ValueError(message)
#     964 return func(*args, **kwargs)
#
# ValueError: _CURRENT_EXPERIMENT global variable is not set. Please run setup() first.
